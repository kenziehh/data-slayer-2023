# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train=pd.read_csv('../../data/processed/cleaned_train.csv')

# %%
df_train.head()
# Out:
#    Id     Make         Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0   1    MITSU           SUV - SMALL        1.500000        4.0          AV8
# 1   2   TOYOTI  PICKUP TRUCK - SMALL        2.978387        6.0           A5
# 2   3  MATSUDA               COMPACT        2.000000        4.0          AS6
# 3   4    CHEVO       VAN - PASSENGER        2.978387        8.0           A6
# 4   5   TOYOTI               COMPACT        1.800000        4.0           M6
#
#   Fuel Type  Fuel Consumption City (L/100km)  Fuel Consumption Hwy (L/100km)  \
# 0         X                        11.904762                        0.072000
# 1         X                        13.793103                        9.700000
# 2         X                        10.204082                        6.077907
# 3         X                         0.173000                       11.700000
# 4         X                         8.100000                        6.577601
#
#    Fuel Consumption Comb (L/100km)  CO2 Emissions(g/km)
# 0                         0.098000                  208
# 1                        11.960000                  325
# 2                         7.406014                  170
# 3                        14.780000                  362
# 4                         8.010000                  180

# %%
df_train.tail()
# Out:
#           Id     Make            Vehicle Class  Engine Size(L)  Cylinders  \
# 54932  54933    CHEVO               SUBCOMPACT             6.2        8.0
# 54933  54934    CHEVO               SUBCOMPACT             3.6        6.0
# 54934  54935     FOLD               TWO-SEATER             3.5        6.0
# 54935  54936    CHEVO  PICKUP TRUCK - STANDARD             6.2        8.0
# 54936  54937  RYUNDAI                FULL-SIZE             2.4        4.0
#
#       Transmission Fuel Type  Fuel Consumption City (L/100km)  \
# 54932         AS10         Z                            11.90
# 54933           M6         X                             0.21
# 54934          AM7         Z                            18.20
# 54935           A8         Z                            18.30
# 54936          AS6         X                             9.70
#
#        Fuel Consumption Hwy (L/100km)  Fuel Consumption Comb (L/100km)  \
# 54932                        8.802817                        10.505360
# 54933                        0.106000                        16.323040
# 54934                       12.500000                        15.630000
# 54935                        9.900000                        14.520000
# 54936                        7.300279                         8.620126
#
#        CO2 Emissions(g/km)
# 54932                  318
# 54933                  303
# 54934                  410
# 54935                  466
# 54936                  192

# %%
df_train.sample(5)
# Out:
#           Id   Make            Vehicle Class  Engine Size(L)  Cylinders  \
# 42178  42179  CHEVO                 MID-SIZE             1.8        4.0
# 47716  47717   JIPU              SUV - SMALL             3.2        6.0
# 24148  24149   FOLD           SUV - STANDARD             5.4        8.0
# 15726  15727    BMV                  COMPACT             3.0        6.0
# 47292  47293   FOLD  SPECIAL PURPOSE VEHICLE             2.5        4.0
#
#       Transmission Fuel Type  Fuel Consumption City (L/100km)  \
# 42178          AS6         X                        11.494253
# 47716           A9         X                         0.123000
# 24148           A6         X                        13.819918
# 15726           M6         Z                        14.005602
# 47292          AS6         X                         0.136000
#
#        Fuel Consumption Hwy (L/100km)  Fuel Consumption Comb (L/100km)  \
# 42178                        6.745483                         9.970090
# 47716                       10.600000                        11.540000
# 24148                        0.122000                        12.174689
# 15726                        8.244479                        12.155814
# 47292                        0.113000                         0.126000
#
#        CO2 Emissions(g/km)
# 42178                  205
# 47716                  248
# 24148                  421
# 15726                  279
# 47292                  256

# %%
df_train.shape
# Out:
# (54937, 11)

# %%
df_train.columns
# Out:
# Index(['Id', 'Make', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100km)',
#        'Fuel Consumption Hwy (L/100km)', 'Fuel Consumption Comb (L/100km)',
#        'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
df_train=df_train.drop('Id',axis=1)
df_train=df_train.dropna()

# %%
df_train.info()
print(df_train.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48617 entries, 0 to 54936
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Make                             48617 non-null  object
#  1   Vehicle Class                    48617 non-null  object
#  2   Engine Size(L)                   48617 non-null  float64
#  3   Cylinders                        48617 non-null  float64
#  4   Transmission                     48617 non-null  object
#  5   Fuel Type                        48617 non-null  object
#  6   Fuel Consumption City (L/100km)  48617 non-null  float64
#  7   Fuel Consumption Hwy (L/100km)   48617 non-null  float64
#  8   Fuel Consumption Comb (L/100km)  48617 non-null  float64
#  9   CO2 Emissions(g/km)              48617 non-null  int64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 4.1+ MB
# Make                                object
# Vehicle Class                       object
# Engine Size(L)                     float64
# Cylinders                          float64
# Transmission                        object
# Fuel Type                           object
# Fuel Consumption City (L/100km)    float64
# Fuel Consumption Hwy (L/100km)     float64
# Fuel Consumption Comb (L/100km)    float64
# CO2 Emissions(g/km)                  int64
# dtype: object

# %%
numeric_columns = df_train.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
correlation_matrix = numeric_columns.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix')
plt.show()

# %%
sns.pairplot(df_train, kind = "reg", diag_kind = "kde", diag_kws={"color":"red"}, plot_kws={"line_kws":{"color":"red"}});
