# %%
import pandas as pd
import numpy as np

# %%
df_train=pd.read_csv('cleaned_train.csv')
df_test=pd.read_csv('cleaned_test.csv')

# %%
null_indexes = df_train[df_train['Transmission'].isnull()].index
null_indexes
# Out:
# Index([     4,      5,     13,     15,     39,     40,     59,     61,     63,
#            92,
#        ...
#        137071, 137086, 137088, 137097, 137099, 137103, 137107, 137124, 137127,
#        137139],
#       dtype='int64', length=10440)

# %%
missing_value = df_train.isnull().sum()
missing_value[0:11]
# Out:
# Id                                     0
# Make                                   0
# Vehicle Class                       5132
# Engine Size(L)                         0
# Cylinders                              0
# Transmission                       10440
# Fuel Type                          10102
# Fuel Consumption City (L/100km)        0
# Fuel Consumption Hwy (L/100km)         0
# Fuel Consumption Comb (L/100km)        0
# CO2 Emissions(g/km)                    0
# dtype: int64

# %%
null_count=df_train['Vehicle Class'].isnull().sum()
null_count
# Out:
# 5132

# %%
df_train['Fuel Consumption City (L/100km)'].plot()
# Out:
# <Axes: >

# %%
df_train['Fuel Consumption Hwy (L/100km)'].plot()
# Out:
# <Axes: >

# %%
df_train['Fuel Consumption Comb (L/100km)']
# Out:
# 0          6.257382
# 1         28.840000
# 2          0.922850
# 3          8.507133
# 4          0.138000
#             ...
# 137136    22.026432
# 137137     3.961182
# 137138     4.506898
# 137139     0.064000
# 137140     3.098853
# Name: Fuel Consumption Comb (L/100km), Length: 137141, dtype: float64
